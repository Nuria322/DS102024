# %% [markdown]
# # Análisis de datos Palmer (pingüinos)
# ![image.png](attachment:image.png)

# %% [markdown]
# Este conjunto de datos contiene información sobre tres especies de pingüinos que habitan en las islas Palmer, en la peninsula Antártica. Las especies incluidas son Adeline, Chisnstrap y Gentoo.

# %% [markdown]
# ### Librerías

# %%
# Tratamiento de datos
import pandas as pd
import numpy as np

# Gráficos

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# Estadística 
import scipy

# %% [markdown]
# ## Carga de datos

# %%
penguins = pd.read_csv('C:/Users/nuria/OneDrive/Escritorio/Data Science/DS102024/2-DataAnalysis/10-EDA/penguins.csv')
penguins.head()
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen             NaN            NaN                NaN
# 4      5  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
df = penguins

# %%
df.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
df.describe(include = 'all')
# Out:
#              rowid species  island  bill_length_mm  bill_depth_mm  \
# count   344.000000     344     344      342.000000     342.000000
# unique         NaN       3       3             NaN            NaN
# top            NaN  Adelie  Biscoe             NaN            NaN
# freq           NaN     152     168             NaN            NaN
# mean    172.500000     NaN     NaN       43.921930      17.151170
# std      99.448479     NaN     NaN        5.459584       1.974793
# min       1.000000     NaN     NaN       32.100000      13.100000
# 25%      86.750000     NaN     NaN       39.225000      15.600000
# 50%     172.500000     NaN     NaN       44.450000      17.300000
# 75%     258.250000     NaN     NaN       48.500000      18.700000
# max     344.000000     NaN     NaN       59.600000      21.500000
#
#         flipper_length_mm  body_mass_g   sex         year
# count          342.000000   342.000000   333   344.000000
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
df.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
print(df['species'].unique())
print(df['island'].unique())
print(df['sex'].unique())
# Out:
# ['Adelie' 'Gentoo' 'Chinstrap']
# ['Torgersen' 'Biscoe' 'Dream']
# ['male' 'female' nan]

# %% [markdown]
# ## Como lo haría Dani
# ctrl + k luego sueltas y le das a la Y

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Se puede observar que los datos estan compuestos por 344 filas y 9 columnas de las cuales ´rowid´ carece de importancia ya que es un índice.

# %% [markdown]
# |Variable|Descripción|
# |---|---|
# |Especie (species)| Adelie, Chinstrap, Gentoo.|
# |Isla (island)| Biscoe, Dream, Torgersen.|
# |Longitud del pico (bill_length_mm)| medida en milímetros.|
# |Profundidad del pico (bill_depth_mm)| medida en milímetros.|
# |Longitud de la aleta (flipper_length_mm)| medida en milímetros.|
# |Masa corporal (body_mass_g)| medida en gramos.|
# |Género (sex)| Macho o Hembra.|
# |Año (year)| Año en que se recolectaron los datos.|

# %% [markdown]
# ## Análisis Exploratorio de datos (EDA)

# %% [markdown]
# ### Análisis Univariado

# %%
# Faltan funciones, información, graficos y conclusiones (mirar el analisis de datos prof, ahí está todo)

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df[df['sex'].isnull()] #El primero y el ultimo lo podemos eleiminar porque no tenemos suficientes datos
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 3        4  Adelie  Torgersen             NaN            NaN
# 8        9  Adelie  Torgersen            34.1           18.1
# 9       10  Adelie  Torgersen            42.0           20.2
# 10      11  Adelie  Torgersen            37.8           17.1
# 11      12  Adelie  Torgersen            37.8           17.3
# 47      48  Adelie      Dream            37.5           18.9
# 178    179  Gentoo     Biscoe            44.5           14.3
# 218    219  Gentoo     Biscoe            46.2           14.4
# 256    257  Gentoo     Biscoe            47.3           13.8
# 268    269  Gentoo     Biscoe            44.5           15.7
# 271    272  Gentoo     Biscoe             NaN            NaN
#
#      flipper_length_mm  body_mass_g  sex  year
# 3                  NaN          NaN  NaN  2007
# 8                193.0       3475.0  NaN  2007
# 9                190.0       4250.0  NaN  2007
# ...

# %% [markdown]
# ## Como lo haría Dani

# %%
numeric_cols = df.select_dtypes(exclude = 'object')
numeric_cols
# Out:
#      rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0        1            39.1           18.7              181.0       3750.0
# 1        2            39.5           17.4              186.0       3800.0
# 2        3            40.3           18.0              195.0       3250.0
# 3        4             NaN            NaN                NaN          NaN
# 4        5            36.7           19.3              193.0       3450.0
# ..     ...             ...            ...                ...          ...
# 339    340            55.8           19.8              207.0       4000.0
# 340    341            43.5           18.1              202.0       3400.0
# 341    342            49.6           18.2              193.0       3775.0
# 342    343            50.8           19.0              210.0       4100.0
# 343    344            50.2           18.7              198.0       3775.0
#
#      year
# 0    2007
# 1    2007
# 2    2007
# 3    2007
# 4    2007
# ...

# %%
df1 = df.copy()
df1 =df.dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              333 non-null    int64
#  1   species            333 non-null    object
#  2   island             333 non-null    object
#  3   bill_length_mm     333 non-null    float64
#  4   bill_depth_mm      333 non-null    float64
#  5   flipper_length_mm  333 non-null    float64
#  6   body_mass_g        333 non-null    float64
#  7   sex                333 non-null    object
#  8   year               333 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 26.0+ KB
