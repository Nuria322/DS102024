# %% [markdown]
# # SQL

# %% [markdown]
# ## Conexión a PostgreSQL usando SQLAlchemy

# %%
import os
import pandas as pd
from typing import Union
from sqlalchemy import create_engine, text

# Reemplaza USER y PASSWORD del .env
engine = create_engine("sqlite:///data/sql-murder-mystery.db")

# Probar la conexión
try:
    connection = engine.connect()
    print("Conexión exitosa")
    connection.close()
except Exception as e:
    print(f"Error al conectar: {e}")


def ejecutar_query(query: str) -> Union[pd.DataFrame, str]:
    """
    Ejecuta una consulta SQL en la base de datos y devuelve un DataFrame.

    Parámetros:
    - query (str): La consulta SQL a ejecutar.

    Retorna:
    - Union[pd.DataFrame, pl.DataFrame, str]: Retorna un DataFrame en pandas o polars dependiendo del parámetro 'devolver_polars',
      o un mensaje de éxito/error si la operación no es un SELECT.
    """
    
    with engine.connect() as connection:
        try:
            result = connection.execute(text(query))
            
            # Determinar si es una consulta SELECT para devolver datos
            if result.returns_rows:
                rows = result.fetchall()
                columns = result.keys()

                # Convertir filas en un diccionario de listas para crear correctamente el DataFrame en polars
                data_dict = {col: [row[idx] for row in rows] for idx, col in enumerate(columns)}

                # Verificación de coincidencia de columnas y filas
                return pd.DataFrame(data_dict)
            else:
                connection.commit()
                return f"Query ejecutada correctamente: {result.rowcount} filas afectadas."
        except Exception as e:
            return f"Error al ejecutar la query: {e}"
# Out:
# Conexión exitosa

# %%
pd.set_option('display.max_colwidth',None)
#pd.set_option('display.max_columns', None) # Alarga la columna

query= """SELECT * 
          FROM crime_scene_report"""


ejecutar_query(query=query)
# Out:
#           date     type  \
# 0     20180115  robbery
# 1     20180115   murder
# 2     20180115   murder
# 3     20180215   murder
# 4     20180215   murder
# ...        ...      ...
# 1223  20180430  bribery
# 1224  20180430    fraud
# 1225  20180430  assault
# 1226  20180501  assault
# 1227  20180115   murder
#
#                                                                                                                                                                                     description  \
# 0                                                                                                                                             A Man Dressed as Spider-Man Is on a Robbery Spree
# 1                                                                                                                                                             Life? Dont talk to me about life.
# 2                                                                                                                                           Mama, I killed a man, put a gun against his head...
# 3                                                                                                                                                                    REDACTED REDACTED REDACTED
# 4                                                                                                                                       Someone killed the guard! He took an arrow to the knee!
# ...                                                                                                                                                                                         ...
# 1223                                                                                                                                                                                         \n
# 1224                                                                                                                                                          ‘Why not?’ said the March Hare.\n
# 1225                                                                                                                                                                                         \n
# 1226                                                                                                                 be NO mistake about it: it was neither more nor less than a pig, and she\n
# 1227  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#               city
# 0              NYC
# 1           Albany
# 2             Reno
# 3         SQL City
# 4         SQL City
# ...            ...
# 1223  Garden Grove
# 1224         Houma
# 1225       Fontana
# 1226       Trenton
# 1227      SQL City
#
# [1228 rows x 4 columns]

# %%
pd.set_option('display.max_colwidth',None)
#pd.set_option('display.max_columns', None) # Alarga la columna

query= """SELECT * 
          FROM crime_scene_report
          WHERE type = 'murder'
          AND city = 'SQL City'
          AND date = '20180115'"""

ejecutar_query(query=query)
# Out:
#        date    type  \
# 0  20180115  murder
#
#                                                                                                                                                                                  description  \
# 0  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#        city
# 0  SQL City

# %%
query ='SELECT * FROM person WHERE address_street_name = "Northwestern Dr" OR address_street_name = "Franklin Ave"'

ejecutar_query(query=query)
# Out:
#        id            name  license_id  address_number address_street_name  \
# 0   10010       Muoi Cary      385336             741     Northwestern Dr
# 1   12207  Wilmer Wolever      509484             139        Franklin Ave
# 2   12711  Norman Apolito      667757             599     Northwestern Dr
# 3   14887  Morty Schapiro      118009            4919     Northwestern Dr
# 4   15171    Weldon Penso      336999             311     Northwestern Dr
# ..    ...             ...         ...             ...                 ...
# 90  96595   Coretta Cubie      303645            3631     Northwestern Dr
# 91  97913  Cameron Dilick      971988            2954        Franklin Ave
# 92  98593     Jonah Toner      578982            2947     Northwestern Dr
# 93  98744   Jordan Myntti      256116            3104        Franklin Ave
# 94  99826    Ivy Kazarian      994470             892     Northwestern Dr
#
#           ssn
# 0   828638512
# 1   636825374
# 2   778264744
# 3   111564949
# 4   131379495
# ..        ...
# 90  378403829
# 91  665147939
# 92  745853548
# 93  876030104
# 94  208359813
#
# [95 rows x 6 columns]

# %%
query= 'SELECT * FROM person WHERE address_street_name = "Northwestern Dr" AND address_number > 4918 '

ejecutar_query(query=query)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %%
query= 'SELECT * FROM person WHERE address_street_name = "Franklin Ave"'

ejecutar_query(query=query)
# Out:
#        id                 name  license_id  address_number  \
# 0   12207       Wilmer Wolever      509484             139
# 1   16371       Annabel Miller      490173             103
# 2   17683        Johnnie Schee      968887            1277
# 3   18651        Carleen Etoll      356746              22
# 4   22636       Zachary Ybarbo      768359             785
# 5   24737           Gema Nantz      273410            3968
# 6   30654      Clarita Rickels      418084            2254
# 7   32264       Shelby Dezeeuw      735415            1391
# 8   33793         Amado Mattan      161915              99
# 9   34592    Cordell Lindamood      592762            3657
# 10  36328         Domenic Laun      971080            3809
# 11  36400         Noe Pancoast      895755            3443
# 12  37616     Katelyn Schwerin      430143             332
# 13  46827         Bev Billiter      643591            2316
# 14  52059        Jordan Pelton      686854            2786
# 15  52075             Ezra Phy      928109             384
# 16  52121       Yelena Whitler      427830            3185
# 17  54817          Guy Bustard      213929             591
# 18  54896        Patty Wamsley      688488            1097
# 19  56142       William Shiver      741336            1926
# 20  57051        Lavette Koehl      137365            2284
# 21  59746        Ronny Gumbert      469722            3197
# 22  60944        Ricki Bidding      443364            2072
# 23  61001      Laurine Bousman      197150             247
# 24  61437     Colette Hollomon      661377             453
# 25  62292       Isaiah Holsten      913856             747
# 26  62520      Mariah Lepetich      450447            3086
# 27  67292       Renita Roperto      801041             625
# 28  69719        Hope Arzabala      311724             841
# 29  70050   Whitney Herkenratt      138462            3445
# 30  75510  Sebastian Ramnarase      333188            1127
# 31  76128         Ressie Razze      633497            1199
# 32  78170          Graig Summy      192325            3387
# 33  78408         Dante Eschen      218173            3447
# 34  78658        Blake Chrones      310242            2014
# 35  78830        Candice Train      814779            3255
# 36  83003       Wilmer Casella      672050            3564
# 37  83754          Maria Walsh      201334            2716
# 38  84531       Edgar Mendieta      315790            3881
# 39  87521          Moses Ikerd      638991            2283
# 40  88966            Raul Eads      570927            2066
# 41  93947        Omer Andreoni      605718              13
# 42  95119            Hong Lisa      825828             375
# 43  97913       Cameron Dilick      971988            2954
# 44  98744        Jordan Myntti      256116            3104
#
#    address_street_name        ssn
# 0         Franklin Ave  636825374
# 1         Franklin Ave  318771143
# 2         Franklin Ave  815977821
# 3         Franklin Ave  193369255
# 4         Franklin Ave  285346605
# 5         Franklin Ave  180545802
# 6         Franklin Ave  714941023
# 7         Franklin Ave  143197463
# 8         Franklin Ave  125205748
# 9         Franklin Ave  509890333
# 10        Franklin Ave  825329637
# 11        Franklin Ave  732212073
# 12        Franklin Ave  392365033
# 13        Franklin Ave  940192302
# 14        Franklin Ave  676224073
# 15        Franklin Ave  176404498
# 16        Franklin Ave  115106155
# 17        Franklin Ave  820850670
# 18        Franklin Ave  725272037
# 19        Franklin Ave  219913461
# 20        Franklin Ave  776046786
# 21        Franklin Ave  561067477
# 22        Franklin Ave  614976330
# 23        Franklin Ave  431360364
# 24        Franklin Ave  314956038
# 25        Franklin Ave  995368430
# 26        Franklin Ave  797745632
# 27        Franklin Ave  894442480
# 28        Franklin Ave  270289620
# 29        Franklin Ave  552518972
# 30        Franklin Ave  315716580
# 31        Franklin Ave  456366143
# 32        Franklin Ave  277793306
# 33        Franklin Ave  135374633
# 34        Franklin Ave  423048084
# 35        Franklin Ave  717570815
# 36        Franklin Ave  569057540
# 37        Franklin Ave  121282864
# 38        Franklin Ave  458847132
# 39        Franklin Ave  797715435
# 40        Franklin Ave  764132739
# 41        Franklin Ave  322594288
# 42        Franklin Ave  113438176
# 43        Franklin Ave  665147939
# 44        Franklin Ave  876030104

# %%
query = """SELECT * FROM person 
WHERE address_street_name = 'Franklin Ave' 
AND name = 'Annabel Miller'"""

ejecutar_query(query=query)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %%
# Entrevista a Annabel
query= 'SELECT * FROM interview WHERE person_id = "16371" '

ejecutar_query(query=query)
# Out:
#    person_id  \
# 0      16371
#
#                                                                                                               transcript
# 0  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
# Entrevista a Morty
query= 'SELECT * FROM interview WHERE person_id = "14887"'

ejecutar_query(query=query)
# Out:
#    person_id  \
# 0      14887
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %%
# The membership number on the bag started with "48Z". Only gold members have those bags.
query= 'SELECT * FROM get_fit_now_member WHERE membership_status = "gold" AND id LIKE "48Z%"'

ejecutar_query(query=query)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
# Joe Germuska
query= 'SELECT * FROM get_fit_now_check_in WHERE membership_id = "48Z7A"'

ejecutar_query(query=query)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730

# %%
# Jeremy Bowers
query= 'SELECT * FROM get_fit_now_check_in WHERE membership_id = "48Z55"'

ejecutar_query(query=query)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z55       20180109           1530            1700

# %%
query= 'SELECT * FROM person WHERE name = "Jeremy Bowers" OR name ="Joe Germuska"'

ejecutar_query(query=query)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  28819   Joe Germuska      173289             111                Fisk Rd
# 1  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  138909730
# 1  871539279

# %%
# The man got into a car with a plate that included "H42W"
query= 'SELECT * FROM drivers_license WHERE id = "423327"'

ejecutar_query(query=query)
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#   car_model
# 0  Spark LS

# %% [markdown]
# ## Solución

# %% [markdown]
# Según mi investigación he llegado a la conclusión de que el asesino fue JEREMY BOWERS y al verificar el resultado en la web me dice lo siguiente:
# "Congrats, you found the murderer! But wait, there's more... If you think you're up for a challenge, try querying the interview transcript of the murderer to find the real villain behind this crime. If you feel especially confident in your SQL skills, try to complete this final step with no more than 2 queries. Use this same INSERT statement with your new suspect to check your answer."

# %%
query= 'SELECT * FROM interview WHERE person_id = "67318"'

ejecutar_query(query=query)
# Out:
#    person_id  \
# 0      67318
#
#                                                                                                                                                                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %%
query= "SELECT * FROM facebook_event_checkin WHERE date LIKE '201712%'"

ejecutar_query(query=query)
# Out:
#       person_id  event_id  \
# 0         31811      8542
# 1         41421      3799
# 2         66493       816
# 3         96520      8784
# 4         33355      1973
# ...         ...       ...
# 1272      24556      1143
# 1273      99716      1143
# 1274      99716      1143
# 1275      99716      1143
# 1276      67318      1143
#
#                                                                     event_name  \
# 0                                                        -- Herbert Prochnow\n
# 1                                         And everywhere this language went,\n
# 2     Just because your doctor has a name for your condition doesn't mean he\n
# 3       Good advice is something a man gives when he is too old to set a bad\n
# 4                                                       He sure is a fun god\n
# ...                                                                        ...
# 1272                                                      SQL Symphony Concert
# 1273                                                      SQL Symphony Concert
# 1274                                                      SQL Symphony Concert
# 1275                                                      SQL Symphony Concert
# 1276                                                      SQL Symphony Concert
#
#           date
# 0     20171203
# 1     20171206
# 2     20171211
# 3     20171218
# 4     20171205
# ...        ...
# 1272  20171224
# 1273  20171206
# 1274  20171212
# 1275  20171229
# 1276  20171206
#
# [1277 rows x 4 columns]

# %%
query= "SELECT * FROM person WHERE id = '99716' "

ejecutar_query(query=query)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  987756388

# %%
query= "SELECT * FROM drivers_license WHERE id = '202298'"

ejecutar_query(query=query)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
#
#   car_model
# 0   Model S

# %% [markdown]
# ## Conclusión final
#
# El asesino fue Jeremy Bowers pero este fue contratado por MIRANDA PRIESTLY
# "Congrats, you found the brains behind the murder! Everyone in SQL City hails you as the greatest SQL detective of all time. Time to break out the champagne!"
