# %% [markdown]
# # Pokemon **

# %% [markdown]
# ### Step 1. Importa las librerías necesarias

# %%
import numpy as np
import pandas as pd
import matplotlib 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Activa matplotlib de forma estática

# %%
# Configura el backend a 'Agg' para gráficos estáticos
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Crea una figura y un conjunto de datos
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

# Crea el gráfico
plt.plot(x, y)

# Añade título y etiquetas
plt.title('Gráfico de Ejemplo')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

# Guarda la figura en un archivo
plt.savefig('grafico_estatico.png')

# %% [markdown]
# ### Step 3. Lee 'pokemon.csv' de esta [url](https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv), lee la primera columna del csv como índice del DataFrame

# %%
data = pd.read_csv(r'https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv')
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ### Step 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# ### Step 5. Haz un scatter plot con `lmplot()`, que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado `data`

# %%
# %matplotlib inline

# Crear el scatter plot con regresión lineal
sns.lmplot(x='Attack', y='Defense', data=data)

# Añadir título
plt.title('Relación entre Ataque y Defensa de Pokémon')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Step 6. No queremos ver la línea recta de la regresión lineal.
# Prueba a añadir fit_reg a falso

# %%
# Crear el scatter plot sin la línea de regresión
sns.lmplot(x='Attack', y='Defense', data=data, fit_reg=False)

# Añadir título
plt.title('Relación entre Ataque y Defensa de Pokémon')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Step 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el `hue` sea el Stage

# %%
print(data.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Crear el scatter plot sin la línea de regresión y codificando por 'Type 2'
sns.lmplot(x='Attack', y='Defense', data=data, fit_reg=False, hue='Type 2')  

plt.title('Relación entre Ataque y Defensa de Pokémon por Stage')

plt.show()

# %% [markdown]
# ### Step 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(x='Attack', y='Defense', data=data, fit_reg=False, hue='Type 2') 
plt.title('Relación entre Ataque y Defensa de Pokémon por Type 2')
# Limitar el eje X entre 20 y 100
plt.xlim(20, 100)

plt.show()

# %% [markdown]
# ### Step 9. Dibuja un diagrama de cajas con el dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
print(data.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data_melted = data.melt(var_name='Variable', value_name='Valor', value_vars=data.select_dtypes(include='number').columns)

# Crear el diagrama de cajas
plt.figure(figsize=(12, 6))
sns.boxplot(x='Variable', y='Valor', data=data_melted)
plt.title('Diagrama de Cajas para Todas las Variables Numéricas')

# Rotar etiquetas del eje x
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Step 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
data_filtered = data.drop(columns=['Total', '#', 'Legendary'])

data_melted = data_filtered.melt(var_name='Variable', value_name='Valor', value_vars=data_filtered.select_dtypes(include='number').columns)

# Crear el diagrama de cajas
plt.figure(figsize=(12, 6))
sns.boxplot(x='Variable', y='Valor', data=data_melted)
plt.title('Diagrama de Cajas para Todas las Variables Numéricas (sin Total, Stage, ni Legendary)')

# Rotar etiquetas del eje x
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Step 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
data['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### Step 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
data[data['Type 1'].isin(['Grass', 'Fire', 'Water'])]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 762  692              Clauncher  Water     NaN    330   50      53       62
# 763  693              Clawitzer  Water     NaN    500   71      73       88
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 740       62       57     52           6      False
# 741       97       81     68           6      False
# 762       58       63     44           6      False
# 763      120       89     59           6      False
# 799      130       90     70           6       True
#
# [234 rows x 13 columns]

# %% [markdown]
# ### Step 13. Usa un estilo 'whitegrid'

# %%
sns.set_style('whitegrid')
# Crear el diagrama de cajas
plt.figure(figsize=(12, 6))
sns.boxplot(x='Variable', y='Valor', data=data_melted)
plt.title('Diagrama de Cajas para Variables Numéricas (Type 1: Grass, Fire, Water)')
# Rotar etiquetas del eje x
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Step 14. Pinta diagramas de violín con el DataFrame

# %%
# Filtrar
filtered_data = data[data['Type 1'].isin(['Grass', 'Fire', 'Water'])]

# Crear el gráfico de violín
plt.figure(figsize=(10, 6))
sns.violinplot(x='Type 1', y='Total', data=filtered_data)
plt.title('Distribución de Totales de Pokémon por Tipo')
plt.xlabel('Tipo de Pokémon')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# ### Step 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colores = ['#78C850', '#F08030', '#6890F0']

# %% [markdown]
# ### Step 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
colores = ['#78C850', '#F08030', '#6890F0']

# Crear el gráfico de violín
plt.figure(figsize=(10, 6))
sns.violinplot(x='Type 1', y='Total', hue='Type 1', data=filtered_data, palette=colores, split=False)
plt.title('Distribución de Totales de Pokémon por Tipo')
plt.xlabel('Tipo de Pokémon')
plt.ylabel('Total')
plt.legend(title='Tipo', loc='upper right')
plt.show()
# Out:
# C:\Users\nuria\AppData\Local\Temp\ipykernel_26504\1121781830.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Tipo', loc='upper right')

# %% [markdown]
# ### Step 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# - Para ver esto, usamos el swarmplot.
# - Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(x='Type 1', y='Total', data=filtered_data, palette=colores)
plt.title('Distribución de Totales de Pokémon por Tipo (Swarmplot)')
plt.xlabel('Tipo de Pokémon')
plt.ylabel('Total')
plt.legend(title='Tipo', loc='upper right', labels=['Grass', 'Fire', 'Water'])
plt.show()
# Out:
# C:\Users\nuria\AppData\Local\Temp\ipykernel_26504\2404570662.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Type 1', y='Total', data=filtered_data, palette=colores)

# %% [markdown]
# ### Step 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9

# %%
colores = ['#78C850', '#F08030', '#6890F0']

plt.figure(figsize=(10, 6))

# Gráfico de violín
sns.violinplot(x='Type 1', y='Total', data=filtered_data, palette=colores, inner=None, alpha=0.9)

# Gráfico de swarm
sns.swarmplot(x='Type 1', y='Total', data=filtered_data, color='k', alpha=0.9)

# Configurar título y etiquetas
plt.title('Distribución de Totales de Pokémon por Tipo')
plt.xlabel('Tipo de Pokémon')
plt.ylabel('Total')
plt.legend(title='Tipo', loc='upper right', labels=['Grass', 'Fire', 'Water'])
plt.show()
# Out:
# C:\Users\nuria\AppData\Local\Temp\ipykernel_26504\1759958331.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Type 1', y='Total', data=filtered_data, palette=colores, inner=None, alpha=0.9)

# %% [markdown]
# ### Step 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
#  Dado un DataFrame, [melt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html) recibe varios parámetros:
#  * qué columnas del DataFrame se quedan igual
#  * qué nombres de columnas del dataframe pasan a ser una columna nueva
#  * cómo queremos llamar esas nuevas columnas
#
# Primero recuerda el Dataframe `df_grass_fire_water` con las primeras 5 filas

# %%
filtered_data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
melted_data = pd.melt(filtered_data, id_vars=['Name', 'Type 1'], 
                       value_vars=['Total', 'HP', 'Attack', 'Defense', 'Speed'], 
                       var_name='Stat', value_name='Value')

# %% [markdown]
# En este caso se quedarían igual Name y Type 1, las columnas nuevas serían Stat y value

# %% [markdown]
# ### Step 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
#
# Escribimos `df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')`

# %%
melted_data = filtered_data.melt(id_vars=['Name', 'Type 1'], 
                                  value_vars=['Total', 'HP', 'Attack', 'Defense', 'Speed'], 
                                  var_name='New Column')

# %%
melted_data.head()
# Out:
#                     Name Type 1 New Column  value
# 0              Bulbasaur  Grass      Total    318
# 1                Ivysaur  Grass      Total    405
# 2               Venusaur  Grass      Total    525
# 3  VenusaurMega Venusaur  Grass      Total    625
# 4             Charmander   Fire      Total    309

# %% [markdown]
# ### Step 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(x='New Column', y='value', hue='Type 1', data=melted_data, dodge=True, alpha=0.8)

# Configurar título y etiquetas
plt.title('Distribución de Estadísticas de Pokémon por Tipo')
plt.xlabel('Estadísticas')
plt.ylabel('Valores')
plt.legend(title='Tipo de Pokémon')
plt.show()
# Out:
# c:\Users\nuria\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-NHz2zIBL-py3.10\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nuria\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-NHz2zIBL-py3.10\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nuria\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-NHz2zIBL-py3.10\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nuria\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-NHz2zIBL-py3.10\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Step 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# Usando plt:
#   - fija el límite del eje Y entre 0 y 200
#   - fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %%
plt.figure(figsize=(10, 6))  # Tamaño de la figura
sns.swarmplot(x='New Column', y='value', hue='Type 1', data=melted_data, dodge=True, palette=['#78C850', '#F08030', '#6890F0'], alpha=0.8, size=4)  # Ajustar el tamaño

# Configurar límites del eje Y
plt.ylim(0, 200)

# Configurar título y etiquetas
plt.title('Distribución de Estadísticas de Pokémon por Tipo')
plt.xlabel('Estadísticas')
plt.ylabel('Valores')

# Fijar la leyenda en la parte superior izquierda
plt.legend(title='Tipo de Pokémon', bbox_to_anchor=(0, 1), loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Step 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
#
# Las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %% [markdown]
# ### Step 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Defense'], kde=True, color='blue', bins=20)

plt.title(' Nivel de Defensa')
plt.xlabel('Nivel de Defensa')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# ### Step 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot y plt.xticks para girar las etiquetas

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Type 1', data=data, palette='viridis', hue=None)

plt.title('Cantidad de Pokémon por Tipo')
plt.xlabel('Tipo de Pokémon')
plt.ylabel('Cantidad')

# Girar las etiquetas del eje x
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\nuria\AppData\Local\Temp\ipykernel_26504\2703202903.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Type 1', data=data, palette='viridis', hue=None)

# %% [markdown]
# ### Step 26. Usa catplot con el DataFrame original.
# Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendariosy divide los colores según el Type 2

# %%
# Crear un nuevo campo para identificar legendarios
data['Legendary'] = data['Legendary'].map({True: 'Legendario', False: 'No Legendario'})

# Crear el catplot
g = sns.catplot(x='Type 1', y='Defense', hue='Type 2', col='Legendary', data=data, kind='strip', height=5, aspect=1)

# Configurar título y etiquetas
g.set_titles('{col_name}')
g.set_axis_labels('Tipo 1', 'Defensa')
g.fig.suptitle('Defensa de Pokémon según Tipo 1 y Tipo 2', y=1.02)

plt.show()

# %% [markdown]
# ### Step 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.

# %%
# Crear el gráfico de curvas de nivel
plt.figure(figsize=(10, 6))
sns.kdeplot(x='Attack', y='Defense', data=data, fill=False,cmap='viridis', thresh=0, levels=10)

# Configurar título y etiquetas
plt.title('Función de Distribución de Probabilidad: Defensa vs Ataque')
plt.xlabel('Ataque')
plt.ylabel('Defensa')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Step 29. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original
